# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/Student_Performance - Student_Performance.csv')

# %%
df.head(10)
df.tail(8)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9992              9               52                         No            9
# 9993              9               58                        Yes            7
# 9994              6               46                        Yes            8
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9992                                 7                 50
# 9993                                 7                 55
# 9994                                 0                 39
# ...

# %%
print(df.head())
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65
# 2                                 2                 45
# 3                                 2                 36
# 4                                 5                 66

# %%
print(df.tail())
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2                 23
# 9996                                 5                 58
# 9997                                 5                 74
# 9998                                 0                 95
# 9999                                 1                 64

# %%
df.fillna(0)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
print(df.duplicated().sum())
# Out:
# 127

# %%
df.isnull()
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0             False            False                       False        False
# 1             False            False                       False        False
# 2             False            False                       False        False
# 3             False            False                       False        False
# 4             False            False                       False        False
# ...             ...              ...                         ...          ...
# 9995          False            False                       False        False
# 9996          False            False                       False        False
# 9997          False            False                       False        False
# 9998          False            False                       False        False
# 9999          False            False                       False        False
#
# ...

# %%
print(df.isnull().sum())
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Hours Studied                        int64
# Previous Scores                      int64
# Extracurricular Activities          object
# Sleep Hours                          int64
# Sample Question Papers Practiced     int64
# Performance Index                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 468.9+ KB

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Hours Studied                        9
# Previous Scores                     60
# Extracurricular Activities           2
# Sleep Hours                          6
# Sample Question Papers Practiced    10
# Performance Index                   91
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
from warnings import simplefilter
simplefilter(action='ignore')

# %%
a=10
b=20
print(a)
b
# Out:
# 10
# 20

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65
# 2                                 2                 45
# 3                                 2                 36
# 4                                 5                 66

# %%
plt.hist(df['Hours Studied'],bins=30,edgecolor='black')
plt.xlabel('Hours Studied')
# Out:
# Text(0.5, 0, 'Hours Studied')

# %%
plt.hist(df['Previous Scores'],bins=10,edgecolor='blue',color='green')
plt.xlabel('Previous Scores')
# Out:
# Text(0.5, 0, 'Previous Scores')

# %%
plt.hist(df['Sleep Hours'],bins=30,edgecolor='red',color='Yellow')
plt.xlabel('Sleep Hours')
# Out:
# Text(0.5, 0, 'Sleep Hours')

# %%
plt.hist(df['Sample Question Papers Practiced'],bins=30,edgecolor='blue',color='red')
plt.xlabel('Sample Question Papers Practiced')
# Out:
# Text(0.5, 0, 'Sample Question Papers Practiced')

# %%
plt.hist(df['Performance Index'],bins=6,edgecolor='Yellow',color='blue')
plt.xlabel('Performance Index')
# Out:
# Text(0.5, 0, 'Performance Index')

# %%
df_numerical = df.select_dtypes(include=np.number)
df_numerical.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Sleep Hours',
#        'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
for i in df_numerical.columns:
    plt.hist(df[i],bins=30,edgecolor='black')
    plt.xlabel(i)
    plt.show()

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65
# 2                                 2                 45
# 3                                 2                 36
# 4                                 5                 66

# %%
for i in df_numerical.columns:
    sn.boxplot(data=df_numerical,x='Performance Index')
    plt.show()

# %%
Q1=df['Performance Index'].quantile(0.25)
Q3=df['Performance Index'].quantile(0.75)

IQR=Q3-Q1 # Inter_quartile_range

lower_bound=Q1-(1.5*IQR)
upper_bound=Q3+(1.5*IQR)
print(Q1,Q3)
print(lower_bound,upper_bound)
# Out:
# 40.0 71.0
# -6.5 117.5

# %%
for i in df:
    sn.boxplot(df, x=i,color='maroon',)
    plt.title(i)
    plt.show()

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
Q1=df['Previous Scores'].quantile(0.25)
print(Q1)

Q3=df['Previous Scores'].quantile(0.75)
print(Q3)

IQR=Q3-Q1
lower=Q1-(1.5*IQR)
print(lower)

upper=Q3+(1.5*IQR)
print(upper)
# Out:
# 54.0
# 85.0
# 7.5
# 131.5

# %%
Q1=df['Sample Question Papers Practiced'].quantile(0.75)
print(Q1)

Q3=df['Sample Question Papers Practiced'].quantile(0.75)
print(Q3)

IQR=Q3-Q1
print(IQR)
lower=Q1-(1.5*IQR)
print(lower)

upper=Q3+(1.5*IQR)
print(upper)
# Out:
# 7.0
# 7.0
# 0.0
# 7.0
# 7.0

# %%
Q1=df['Performance Index'].quantile(0.25)
print(Q1)

Q3=df['Performance Index'].quantile(0.75)
print(Q3)

IQR=Q3-Q1
print(IQR)
lower=Q1-(1.5*IQR)
print(lower)

upper=Q3+(1.5*IQR)
print(upper)
# Out:
# 40.0
# 71.0
# 31.0
# -6.5
# 117.5

# %%
Q1=df['Hours Studied'].quantile(0.25)
print(Q1)

Q3=df['Hours Studied'].quantile(0.75)
print(Q3)

IQR=Q3-Q1
print(IQR)
lower=Q1+(1.5*IQR)

upper=Q3+(1.5*IQR)
print(upper)
# Out:
# 3.0
# 7.0
# 4.0
# 13.0

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
for i in df.columns:
    if i not in ['Previous Scores','Performance Index','Hours Studied']:
        plt.figure(figsize=(10, 5)) #(width,height)
        sn.countplot(data=df, x=i, palette='muted')
        plt.title(f'Frequency Distribution of {i}')
        plt.show()

# %%
for i in df.columns:
    if i not in ['Performance Index'] :
        plt.figure(figsize=(10, 6))
        counts=df[i].value_counts()
        plt.pie(counts,labels=counts.index,autopct='%.1f%%')
        plt.title(i)

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['Previous Scores'],df['Performance Index'])
plt.title(' scatter Previous Scores vs Performance Index ')
# Out:
# Text(0.5, 1.0, ' scatter Previous Scores vs Performance Index ')

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['Previous Scores'],df['Performance Index'])
plt.title('Previous Scores vs. Performance Index')
plt.xlabel('Previous Scores')
plt.ylabel('Performance Index')
# Out:
# Text(0, 0.5, 'Performance Index')

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
pd.crosstab(columns=df['Performance Index'],index=df['Sample Question Papers Practiced'])
# Out:
# Performance Index                 10   11   12   13   14   15   16   17   18   \
# Sample Question Papers Practiced
# 0                                   0    0    0    2    1    4    2    7    5
# 1                                   0    0    0    2    1    2    6    3    7
# 2                                   0    2    1    1    0    4    3    1    6
# 3                                   0    1    4    1    0    4    2    4    3
# 4                                   0    1    0    0    1    2    2    4    4
# 5                                   0    1    1    1    1    3    4    5    6
# 6                                   0    0    1    3    2    3    3    1    2
# 7                                   0    0    0    0    0    1    3    4    5
# 8                                   0    0    1    0    0    3    2    2    7
# 9                                   1    0    0    3    1    0    3    4    6
#
# ...

# %%
pd.crosstab(columns=df['Extracurricular Activities'],index=df['Hours Studied']).plot(kind='barh',figsize=(10,8))
# Out:
# <Axes: ylabel='Hours Studied'>

# %%
df['Performance Index'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Sample Question Papers Practiced'].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df.head(2)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1                 91
# 1                                 2                 65

# %%
df.groupby('Hours Studied')['Sample Question Papers Practiced'].sum().reset_index()
# Out:
#    Hours Studied  Sample Question Papers Practiced
# 0              1                              5237
# 1              2                              4924
# 2              3                              4984
# 3              4                              5041
# 4              5                              4995
# 5              6                              5192
# 6              7                              5215
# 7              8                              4902
# 8              9                              5343

# %%
plt.figure(figsize=(10, 5))
average_runs = df.groupby('Hours Studied')['Sample Question Papers Practiced'].sum().reset_index()
print(average_runs)


plt.plot(average_runs['Hours Studied'].astype('str'),average_runs['Sample Question Papers Practiced'],marker='+')
plt.title('Hours Studieds vs Sample Question Papers Practiced')
plt.xlabel('Hours Studied')
plt.ylabel('Sample Question Papers Practiced')
# Out:
#    Hours Studied  Sample Question Papers Practiced
# 0              1                              5237
# 1              2                              4924
# 2              3                              4984
# 3              4                              5041
# 4              5                              4995
# 5              6                              5192
# 6              7                              5215
# 7              8                              4902
# 8              9                              5343
# Text(0, 0.5, 'Sample Question Papers Practiced')

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df_numerical.corr()
# Out:
#                                   Hours Studied  Previous Scores  Sleep Hours  \
# Hours Studied                          1.000000        -0.012390     0.001245
# Previous Scores                       -0.012390         1.000000     0.005944
# Sleep Hours                            0.001245         0.005944     1.000000
# Sample Question Papers Practiced       0.017463         0.007888     0.003990
# Performance Index                      0.373730         0.915189     0.048106
#
#                                   Sample Question Papers Practiced  \
# Hours Studied                                             0.017463
# Previous Scores                                           0.007888
# Sleep Hours                                               0.003990
# Sample Question Papers Practiced                          1.000000
# Performance Index                                         0.043268
#
#                                   Performance Index
# ...

# %%
correlation_matrix = df_numerical.corr()

plt.figure(figsize=(10, 6))
sn.heatmap(correlation_matrix,annot=True,fmt=".2g")
plt.title('Correlation Heatmap of Batting Statistics')
plt.show()

# %%
##ML
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
x=df[['Performance Index']].values
y=df['Hours Studied'].values
x.shape,y.shape
# Out:
# ((10000, 1), (10000,))

# %%
pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

# %%
y_pred=model.predict(x_test)
print(y_pred)
# Out:
# [4.75908925 3.17036163 4.50284286 ... 3.83660224 5.68157625 3.63160513]

# %%
print(y_test)
# Out:
# [5 2 7 ... 5 3 6]

# %%
plt.scatter(x_test, y_test, color='blue',label='Actual')
plt.scatter(x_test, y_pred, color='green', label='Prediction')
plt.plot(x_test, y_pred, color='red', label='Regression Line')
plt.xlabel('Performance Index')
plt.ylabel('Hours Studied')
plt.title('Performance Index vs Hours Studied')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# %%
r2=r2_score(y_test, y_pred)
mse=mean_squared_error(y_test, y_pred)
rmse=np.sqrt(mse)

# %%
print(f"R² Score: {r2:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# %%
print(f'R2 score:{r2:4f}')
print(f'Mean Squared Error:{mse:4f}')
print(f'NP.SQRT:{rmse:4f}')
# Out:
# R2 score:0.129964
# Mean Squared Error:5.756899
# NP.SQRT:2.399354
